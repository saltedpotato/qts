# %%
import polars as pl
import numpy as np
from datetime import datetime, timedelta
import json
import os

from data.cons_data import get_cons
from data.market_data import market_data

from utils.market_time import market_hours
from utils.params import PARAMS
from utils.clustering_methods import Clustering_methods

from pairs_finding.pairs_identification import cointegration_pairs
from pairs_finding.clustering import Clustering

from trade.pairs_trader import PairsTrader
from trade.optimizer import optimizer

import warnings

warnings.filterwarnings("ignore")

# %%
params = {
    ("GOOGL", "GOOG"): {
        PARAMS.beta_win: 100,
        PARAMS.z_win: 10,
        PARAMS.z_entry: 2,
        PARAMS.z_exit: 1,
        PARAMS.trade_freq: "1m",
    },
    ("GOOGL", "AAPL"): {
        PARAMS.beta_win: 100,
        PARAMS.z_win: 10,
        PARAMS.z_entry: 2,
        PARAMS.z_exit: 1,
        PARAMS.trade_freq: "5m",
    },
}

# %%
etf = "QQQ"
cons = get_cons(etf=etf)
cons_date = cons.read()

data = market_data(
    file_path="C:/Users/edmun/OneDrive/Desktop/Quantitative Trading Strategies/Project/qts/data/polygon/*.parquet"
)
out_path = "output/polygon"
earliest_date_year = [
    i
    for i in cons_date.keys()
    if datetime.strptime(i, "%Y-%m-%d").date()
    >= datetime.strptime("2020-06-30", "%Y-%m-%d").date()
]

periods = 30

period_ends = (
    pl.DataFrame(earliest_date_year, schema=["Date"])
    .with_columns(
        pl.all().cast(pl.Date),
    )
    .with_columns((pl.col("Date").rank() // periods).alias("Chunk"))
    .group_by("Chunk", maintain_order=True)
    .agg(pl.col("Date").last())["Date"]
    .dt.strftime("%Y-%m-%d")
    .to_list()
)

# %%
output = {}
for i in range(10, len(period_ends)):  # range(2, len(period_ends))
    warm_start, train_start, train_end, trade_end = (
        period_ends[i - 10],
        period_ends[i - 2],
        period_ends[i - 1],
        period_ends[i],
    )

    print(warm_start, train_start, train_end, trade_end)
    # next trading day
    last_date = datetime.strptime(train_end, "%Y-%m-%d")
    next_day = (last_date + timedelta(days=1)).strftime("%Y-%m-%d")

    if os.path.isfile((f"{out_path}/result/result_{next_day}_{trade_end}.csv")):
        continue
    # TRAINING PERIOD FINDING OPTIMAL PARAMS #
    data.read(cons=cons_date[train_end], start=train_start, end=train_end)

    train = data.filter(resample_freq="15m", hours=market_hours.MARKET)

    c = Clustering(df=train.select(pl.all().exclude(["date", "time"])))

    # c.run_clustering(method=Clustering_methods.kmeans, min_clusters=2, max_clusters=6)

    c.run_clustering(method=Clustering_methods.agnes, min_clusters=2, max_clusters=5)

    find_pairs = cointegration_pairs(
        df=train.select(pl.all().exclude(["date", "time"])),
        p_val_cutoff=0.005,
        cluster_pairs=c.cluster_pairs,
    )
    find_pairs.identify_pairs()
    for_j = find_pairs.get_top_pairs()
    
    output[f'{train_start}_{train_end}'] = for_j
# Out:
# 2020-08-10 2021-07-23 2021-09-03 2021-10-18
# 2020-09-22 2021-09-03 2021-10-18 2021-11-30
# 2020-11-03 2021-10-18 2021-11-30 2022-01-12
# 2020-12-16 2021-11-30 2022-01-12 2022-02-25
# 2021-02-01 2022-01-12 2022-02-25 2022-04-08
# 2021-03-16 2022-02-25 2022-04-08 2022-05-23
# 2021-04-28 2022-04-08 2022-05-23 2022-07-07
# 2021-06-10 2022-05-23 2022-07-07 2022-08-18
# 2021-07-23 2022-07-07 2022-08-18 2022-09-30
# 2021-09-03 2022-08-18 2022-09-30 2022-11-11
# 2021-10-18 2022-09-30 2022-11-11 2022-12-27
# 2021-11-30 2022-11-11 2022-12-27 2023-02-09
# 2022-01-12 2022-12-27 2023-02-09 2023-03-24
# 2022-02-25 2023-02-09 2023-03-24 2023-05-08
# 2022-04-08 2023-03-24 2023-05-08 2023-06-21
# 2022-05-23 2023-05-08 2023-06-21 2023-08-03
# 2022-07-07 2023-06-21 2023-08-03 2023-09-15
# 2022-08-18 2023-08-03 2023-09-15 2023-10-27
# 2022-09-30 2023-09-15 2023-10-27 2023-12-11
# 2022-11-11 2023-10-27 2023-12-11 2024-01-25
# 2022-12-27 2023-12-11 2024-01-25 2024-03-08
# 2023-02-09 2024-01-25 2024-03-08 2024-04-22
# 2023-03-24 2024-03-08 2024-04-22 2024-06-04
# 2023-05-08 2024-04-22 2024-06-04 2024-07-18
# 2023-06-21 2024-06-04 2024-07-18 2024-08-29
# 2023-08-03 2024-07-18 2024-08-29 2024-10-11
# 2023-09-15 2024-08-29 2024-10-11 2024-11-22
# 2023-10-27 2024-10-11 2024-11-22 2025-01-08
# 2023-12-11 2024-11-22 2025-01-08 2025-02-24
# 2024-01-25 2025-01-08 2025-02-24 2025-04-07
# 2024-03-08 2025-02-24 2025-04-07 2025-05-01

# %%
output
# Out:
# {'2021-07-23_2021-09-03': [('AMD', 'ATVI'),
#   ('CSX', 'IDXX'),
#   ('SIRI', 'VRTX'),
#   ('BIDU', 'INTC'),
#   ('MTCH', 'SWKS'),
#   ('ANSS', 'INTC'),
#   ('SBUX', 'SWKS'),
#   ('ALGN', 'ATVI'),
#   ('MAR', 'SWKS'),
#   ('ADBE', 'INTU'),
#   ('CTSH', 'SWKS'),
#   ('GILD', 'SWKS'),
#   ('CPRT', 'INTC'),
#   ('ADBE', 'AEP'),
#   ('FB', 'FOX'),
#   ('FOXA', 'IDXX'),
#   ('AAPL', 'AEP'),
#   ('BIIB', 'SWKS'),
#   ('CMCSA', 'CTAS'),
#   ('KLAC', 'TXN')],
#  '2021-09-03_2021-10-18': [('CERN', 'KHC'),
#   ('ASML', 'KHC'),
#   ('MRNA', 'REGN'),
#   ('IDXX', 'KHC'),
#   ('INCY', 'KHC'),
#   ('CDNS', 'KHC'),
#   ('ADBE', 'KHC'),
#   ('ANSS', 'EXC'),
#   ('AMZN', 'DOCU'),
#   ('FOXA', 'KHC'),
#   ('FOX', 'KHC'),
#   ('ILMN', 'KHC'),
#   ('BIIB', 'KHC'),
#   ('AMZN', 'COST'),
#   ('GOOG', 'NVDA'),
#   ('GILD', 'KHC'),
#   ('EXC', 'VRSN'),
#   ('CERN', 'VRTX'),
#   ('GOOG', 'HON'),
#   ('AMZN', 'WBA'),
#   ('DLTR', 'MTCH'),
#   ('LULU', 'MTCH')],
#  '2021-10-18_2021-11-30': [('FOX', 'FOXA'),
#   ('KDP', 'PCAR'),
#   ('DOCU', 'ZM'),
#   ('MSFT', 'PEP'),
#   ('CDNS', 'SNPS'),
#   ('HON', 'TMUS'),
#   ('NXPI', 'PEP'),
#   ('KLAC', 'PEP'),
#   ('BIDU', 'INTU'),
#   ('CTAS', 'PEP'),
#   ('LULU', 'PEP'),
#   ('MNST', 'MRNA'),
#   ('ALGN', 'PEP'),
#   ('GOOG', 'PEP'),
#   ('GOOGL', 'PEP'),
#   ('ADP', 'CDNS'),
#   ('ADP', 'SNPS'),
#   ('DXCM', 'PEP'),
#   ('MCHP', 'PEP'),
#   ('ANSS', 'PEP')],
#  '2021-11-30_2022-01-12': [('TSLA', 'NXPI'),
#   ('ADP', 'NXPI'),
#   ('CSX', 'PYPL'),
#   ('AMAT', 'PYPL'),
#   ('PTON', 'WBA'),
#   ('ROST', 'NXPI'),
#   ('MTCH', 'NXPI'),
#   ('PTON', 'MRNA'),
#   ('CDNS', 'MCHP'),
#   ('MAR', 'NXPI'),
#   ('AAPL', 'PYPL'),
#   ('FAST', 'PYPL'),
#   ('KLAC', 'NXPI'),
#   ('AMAT', 'NXPI'),
#   ('KDP', 'PTON'),
#   ('CSX', 'NXPI'),
#   ('LRCX', 'NXPI'),
#   ('FTNT', 'SIRI'),
#   ('PTON', 'VRTX'),
#   ('MCHP', 'PYPL')],
#  '2022-01-12_2022-02-25': [('BIIB', 'SBUX'),
#   ('BIIB', 'CTAS'),
#   ('ADSK', 'BIIB'),
#   ('BIIB', 'CPRT'),
#   ('BIIB', 'ROST'),
#   ('ZM', 'BIIB'),
#   ('BIIB', 'DXCM'),
#   ('ADSK', 'CMCSA'),
#   ('BIIB', 'VRSN'),
#   ('BIIB', 'EBAY'),
#   ('CPRT', 'NXPI'),
#   ('BIIB', 'MNST'),
#   ('AMGN', 'DXCM'),
#   ('CMCSA', 'MDLZ'),
#   ('AMD', 'KDP'),
#   ('CMCSA', 'BIIB'),
#   ('BIIB', 'FAST'),
#   ('BIIB', 'ILMN'),
#   ('QCOM', 'KDP'),
#   ('ADBE', 'XEL'),
#   ('FB', 'PYPL')],
#  '2022-02-25_2022-04-08': [('BIIB', 'IDXX'),
#   ('FB', 'FISV'),
#   ('CMCSA', 'VRSN'),
#   ('FB', 'PANW'),
#   ('DXCM', 'FISV'),
#   ('DDOG', 'EA'),
#   ('AMZN', 'HON'),
#   ('AAPL', 'SNPS'),
#   ('ABNB', 'CRWD'),
#   ('CMCSA', 'IDXX'),
#   ('ABNB', 'HON'),
#   ('BIIB', 'CMCSA'),
#   ('HON', 'NVDA'),
#   ('ADSK', 'ANSS'),
#   ('FISV', 'TSLA'),
#   ('AVGO', 'HON'),
#   ('ANSS', 'ZM'),
#   ('ANSS', 'EA'),
#   ('ADI', 'MELI'),
#   ('ALGN', 'EA')],
#  '2022-04-08_2022-05-23': [('ADBE', 'AEP'),
#   ('AEP', 'TMUS'),
#   ('EBAY', 'MSFT'),
#   ('ILMN', 'SWKS'),
#   ('CTSH', 'SWKS'),
#   ('DXCM', 'SWKS'),
#   ('HON', 'MCHP'),
#   ('PAYX', 'SWKS'),
#   ('ASML', 'ISRG'),
#   ('KHC', 'MDLZ'),
#   ('SPLK', 'SWKS'),
#   ('OKTA', 'SWKS'),
#   ('ADP', 'AEP'),
#   ('INTU', 'SWKS'),
#   ('ABNB', 'SWKS'),
#   ('CRWD', 'SWKS'),
#   ('ASML', 'BIIB'),
#   ('ADSK', 'AEP'),
#   ('BIIB', 'TXN'),
#   ('ABNB', 'ZS')],
#  '2022-05-23_2022-07-07': [('CSCO', 'NVDA'),
#   ('EBAY', 'SWKS'),
#   ('ATVI', 'VRSK'),
#   ('ATVI', 'ORLY'),
#   ('JD', 'PDD'),
#   ('CPRT', 'MSFT'),
#   ('DOCU', 'EBAY'),
#   ('EBAY', 'FAST'),
#   ('ANSS', 'NFLX'),
#   ('AMZN', 'SNPS'),
#   ('ALGN', 'WDAY'),
#   ('ADBE', 'EBAY'),
#   ('ADI', 'CSX'),
#   ('CRWD', 'ZM'),
#   ('DDOG', 'SBUX'),
#   ('NFLX', 'SPLK'),
#   ('MELI', 'NFLX'),
#   ('MRNA', 'ORLY'),
#   ('TEAM', 'ZM'),
#   ('CSX', 'MCHP')],
#  '2022-07-07_2022-08-18': [('ABNB', 'PYPL'),
#   ('ABNB', 'SBUX'),
#   ('CPRT', 'EBAY'),
#   ('KDP', 'PDD'),
#   ('AMD', 'MCHP'),
#   ('CDNS', 'PCAR'),
#   ('AMD', 'EBAY'),
#   ('EBAY', 'NVDA'),
#   ('AMD', 'SWKS'),
#   ('AAPL', 'ORLY'),
#   ('ADSK', 'AVGO'),
#   ('AMAT', 'NVDA'),
#   ('ASML', 'EBAY'),
#   ('FISV', 'PCAR'),
#   ('AMD', 'CPRT'),
#   ('ALGN', 'AZN'),
#   ('ASML', 'AZN'),
#   ('ADI', 'AZN'),
#   ('CTAS', 'PDD'),
#   ('HON', 'PAYX'),
#   ('ILMN', 'ISRG'),
#   ('FTNT', 'MTCH')],
#  '2022-08-18_2022-09-30': [('FAST', 'SGEN'),
#   ('CSX', 'LRCX'),
#   ('CSX', 'MRNA'),
#   ('COST', 'LRCX'),
#   ('AMZN', 'MRNA'),
#   ('ALGN', 'MRNA'),
#   ('AVGO', 'MRNA'),
#   ('EBAY', 'MRNA'),
#   ('AMAT', 'PCAR'),
#   ('FISV', 'MRNA'),
#   ('CTSH', 'MRNA'),
#   ('MRNA', 'WBA'),
#   ('ISRG', 'MRNA'),
#   ('AZN', 'SNPS'),
#   ('MAR', 'PYPL'),
#   ('MRNA', 'VRSK'),
#   ('KLAC', 'MRNA'),
#   ('AZN', 'PCAR'),
#   ('GOOGL', 'HON'),
#   ('GOOG', 'HON')],
#  '2022-09-30_2022-11-11': [('PANW', 'WDAY'),
#   ('CPRT', 'LULU'),
#   ('IDXX', 'LULU'),
#   ('BIIB', 'HON'),
#   ('ORLY', 'VRTX'),
#   ('TMUS', 'VRTX'),
#   ('MAR', 'ZM'),
#   ('AZN', 'MNST'),
#   ('CSCO', 'VRTX'),
#   ('BKNG', 'CMCSA'),
#   ('CRWD', 'TSLA'),
#   ('GOOG', 'REGN'),
#   ('GOOGL', 'REGN'),
#   ('BKNG', 'EA'),
#   ('CTAS', 'LULU'),
#   ('AZN', 'PCAR'),
#   ('EA', 'VRTX'),
#   ('CTAS', 'INTC'),
#   ('BIIB', 'MDLZ'),
#   ('ROST', 'VRTX')],
#  '2022-11-11_2022-12-27': [('EBAY', 'INTC'),
#   ('DLTR', 'KHC'),
#   ('FTNT', 'LRCX'),
#   ('PANW', 'VRTX'),
#   ('FANG', 'KHC'),
#   ('MAR', 'VRTX'),
#   ('KHC', 'PYPL'),
#   ('BIIB', 'ZS'),
#   ('KHC', 'ZM'),
#   ('AMD', 'BIIB'),
#   ('CMCSA', 'CTAS'),
#   ('MAR', 'WBD'),
#   ('COST', 'ZS'),
#   ('MAR', 'QCOM'),
#   ('SIRI', 'ZS'),
#   ('ENPH', 'REGN'),
#   ('QCOM', 'VRTX'),
#   ('MAR', 'PAYX'),
#   ('MCHP', 'REGN'),
#   ('AMD', 'EA')],
#  '2022-12-27_2023-02-09': [('BIIB', 'DXCM'),
#   ('PDD', 'SBUX'),
#   ('COST', 'DLTR'),
#   ('ZS', 'EXC'),
#   ('QCOM', 'DLTR'),
#   ('ANSS', 'NXPI'),
#   ('WBD', 'EBAY'),
#   ('WDAY', 'AMGN'),
#   ('WDAY', 'EXC'),
#   ('CTSH', 'DLTR'),
#   ('WDAY', 'ZS'),
#   ('NFLX', 'DLTR'),
#   ('PANW', 'EXC'),
#   ('WBD', 'DLTR'),
#   ('AAPL', 'ANSS'),
#   ('KLAC', 'WBA'),
#   ('NVDA', 'SNPS'),
#   ('ABNB', 'ANSS'),
#   ('AEP', 'ATVI'),
#   ('TMUS', 'VRSK'),
#   ('META', 'ALGN')],
#  '2023-02-09_2023-03-24': [('CSGP', 'ORLY'),
#   ('ADSK', 'CTAS'),
#   ('AMZN', 'LRCX'),
#   ('SBUX', 'CSGP'),
#   ('SIRI', 'KHC'),
#   ('ADP', 'ORLY'),
#   ('ASML', 'DXCM'),
#   ('JD', 'CSGP'),
#   ('CSGP', 'CTAS'),
#   ('JD', 'CTAS'),
#   ('ODFL', 'TEAM'),
#   ('AZN', 'COST'),
#   ('ADBE', 'DXCM'),
#   ('GFS', 'TXN'),
#   ('LRCX', 'DXCM'),
#   ('BIIB', 'CTAS'),
#   ('SBUX', 'CTAS'),
#   ('JD', 'PAYX'),
#   ('CMCSA', 'CTAS'),
#   ('ADP', 'ODFL')],
#  '2023-03-24_2023-05-08': [('ADBE', 'KHC'),
#   ('ANSS', 'KHC'),
#   ('EA', 'EXC'),
#   ('ILMN', 'SGEN'),
#   ('GOOG', 'PAYX'),
#   ('GOOGL', 'PAYX'),
#   ('GOOG', 'XEL'),
#   ('KDP', 'MDLZ'),
#   ('CSCO', 'CSX'),
#   ('MNST', 'SGEN'),
#   ('GOOGL', 'XEL'),
#   ('DLTR', 'GOOGL'),
#   ('ADSK', 'NXPI'),
#   ('KHC', 'REGN'),
#   ('CPRT', 'ORLY'),
#   ('KHC', 'QCOM'),
#   ('DLTR', 'GOOG'),
#   ('ASML', 'EXC'),
#   ('CSCO', 'FISV'),
#   ('AMAT', 'EXC'),
#   ('META', 'MSFT')],
#  '2023-05-08_2023-06-21': [('ALGN', 'PYPL'),
#   ('DXCM', 'PYPL'),
#   ('ABNB', 'PYPL'),
#   ('CSX', 'PYPL'),
#   ('PCAR', 'PYPL'),
#   ('HON', 'PYPL'),
#   ('INTC', 'PYPL'),
#   ('FAST', 'PYPL'),
#   ('AAPL', 'PYPL'),
#   ('COST', 'PYPL'),
#   ('CTAS', 'PYPL'),
#   ('PANW', 'PYPL'),
#   ('PAYX', 'PYPL'),
#   ('ADP', 'PYPL'),
#   ('ISRG', 'PYPL'),
#   ('ODFL', 'PYPL'),
#   ('CSGP', 'PYPL'),
#   ('INTU', 'PYPL'),
#   ('FTNT', 'ISRG'),
#   ('ADBE', 'PYPL')],
#  '2023-06-21_2023-08-03': [('ENPH', 'ORLY'),
#   ('CMCSA', 'CRWD'),
#   ('CRWD', 'ON'),
#   ('INTC', 'WDAY'),
#   ('ADP', 'CRWD'),
#   ('MDLZ', 'MELI'),
#   ('AMD', 'AMZN'),
#   ('ADP', 'ZS'),
#   ('DLTR', 'INTU'),
#   ('DLTR', 'ROST'),
#   ('ODFL', 'ZS'),
#   ('ADSK', 'AMZN'),
#   ('ADBE', 'CRWD'),
#   ('COST', 'ZS'),
#   ('ABNB', 'ZS'),
#   ('BKNG', 'NVDA'),
#   ('INTU', 'ZS'),
#   ('BKNG', 'ZS'),
#   ('INTC', 'ROST'),
#   ('LRCX', 'WDAY'),
#   ('EBAY', 'TXN'),
#   ('EA', 'TXN')],
#  '2023-08-03_2023-09-15': [('MELI', 'TEAM'),
#   ('INTC', 'TEAM'),
#   ('PDD', 'TEAM'),
#   ('FANG', 'TEAM'),
#   ('CRWD', 'TEAM'),
#   ('AMAT', 'AMGN'),
#   ('BIIB', 'MCHP'),
#   ('MU', 'TEAM'),
#   ('MSFT', 'TEAM'),
#   ('ADBE', 'AMGN'),
#   ('ABNB', 'TEAM'),
#   ('AMZN', 'GFS'),
#   ('ABNB', 'BKNG'),
#   ('ANSS', 'TEAM'),
#   ('ADSK', 'AMGN'),
#   ('INTU', 'TEAM'),
#   ('GILD', 'MDLZ'),
#   ('LCID', 'MCHP'),
#   ('CRWD', 'KDP'),
#   ('GILD', 'PEP'),
#   ('DDOG', 'FTNT')],
#  '2023-09-15_2023-10-27': [('MCHP', 'ODFL'),
#   ('EBAY', 'GFS'),
#   ('AAPL', 'MU'),
#   ('ANSS', 'MAR'),
#   ('ADI', 'GFS'),
#   ('CSCO', 'MAR'),
#   ('ADI', 'PYPL'),
#   ('ODFL', 'TTD'),
#   ('DDOG', 'MAR'),
#   ('ODFL', 'QCOM'),
#   ('MCHP', 'TTD'),
#   ('HON', 'WBD'),
#   ('DDOG', 'QCOM'),
#   ('CSX', 'MAR'),
#   ('EBAY', 'TEAM'),
#   ('SNPS', 'ZS'),
#   ('DDOG', 'TEAM'),
#   ('CDNS', 'META'),
#   ('ILMN', 'MAR'),
#   ('AMAT', 'TTD')],
#  '2023-10-27_2023-12-11': [('LULU', 'ON'),
#   ('ABNB', 'ON'),
#   ('NXPI', 'ON'),
#   ('CRWD', 'ON'),
#   ('ON', 'QCOM'),
#   ('IDXX', 'ON'),
#   ('MCHP', 'ON'),
#   ('KHC', 'ON'),
#   ('COST', 'ON'),
#   ('DLTR', 'ON'),
#   ('ADSK', 'ON'),
#   ('FAST', 'ON'),
#   ('HON', 'ON'),
#   ('FANG', 'ON'),
#   ('ON', 'ZM'),
#   ('CSX', 'ON'),
#   ('DXCM', 'ON'),
#   ('ON', 'WDAY'),
#   ('ON', 'PCAR'),
#   ('ENPH', 'ON')],
#  '2023-12-11_2024-01-25': [('WBA', 'VRTX'),
#   ('ON', 'VRTX'),
#   ('CHTR', 'HON'),
#   ('TSLA', 'VRTX'),
#   ('NVDA', 'SPLK'),
#   ('HON', 'VRTX'),
#   ('BKR', 'VRTX'),
#   ('AVGO', 'CDNS'),
#   ('IDXX', 'VRTX'),
#   ('PEP', 'SIRI'),
#   ('PDD', 'VRTX'),
#   ('LULU', 'VRTX'),
#   ('CSGP', 'VRTX'),
#   ('AMD', 'SPLK'),
#   ('DASH', 'TEAM'),
#   ('MELI', 'XEL'),
#   ('CRWD', 'SIRI'),
#   ('NXPI', 'SIRI'),
#   ('WDAY', 'VRTX'),
#   ('BIIB', 'VRTX')],
#  '2024-01-25_2024-03-08': [('KDP', 'CSX'),
#   ('AMZN', 'SNPS'),
#   ('IDXX', 'ODFL'),
#   ('TXN', 'CSX'),
#   ('GEHC', 'WBA'),
#   ('KDP', 'ORLY'),
#   ('KLAC', 'PCAR'),
#   ('WBA', 'PCAR'),
#   ('KLAC', 'NXPI'),
#   ('WBA', 'DLTR'),
#   ('AMAT', 'WBA'),
#   ('AVGO', 'CSX'),
#   ('LRCX', 'CSX'),
#   ('ODFL', 'SNPS'),
#   ('KHC', 'MDLZ'),
#   ('CSX', 'SNPS'),
#   ('ABNB', 'PEP'),
#   ('WBA', 'CSX'),
#   ('AMAT', 'KLAC'),
#   ('EXC', 'VRSK'),
#   ('CRWD', 'INTC'),
#   ('AZN', 'INTC'),
#   ('CRWD', 'PYPL'),
#   ('DASH', 'FTNT'),
#   ('META', 'PYPL')],
#  '2024-03-08_2024-04-22': [('CRWD', 'MELI'),
#   ('ROP', 'VRTX'),
#   ('GILD', 'SIRI'),
#   ('CTSH', 'EA'),
#   ('AMZN', 'DDOG'),
#   ('CRWD', 'GFS'),
#   ('ADSK', 'CRWD'),
#   ('GFS', 'MELI'),
#   ('AMD', 'EA'),
#   ('MELI', 'TXN'),
#   ('GFS', 'IDXX'),
#   ('CHTR', 'VRSK'),
#   ('KDP', 'KHC'),
#   ('INTU', 'MRNA'),
#   ('CEG', 'MU'),
#   ('BIIB', 'CSCO'),
#   ('CHTR', 'MNST'),
#   ('CRWD', 'CSCO'),
#   ('ADSK', 'MELI'),
#   ('GOOGL', 'WBD')],
#  '2024-04-22_2024-06-04': [('ADSK', 'ZS'),
#   ('META', 'TSLA'),
#   ('CSGP', 'ROST'),
#   ('ADSK', 'TSLA'),
#   ('AAPL', 'GOOGL'),
#   ('ROST', 'TSLA'),
#   ('CDNS', 'MSFT'),
#   ('CDW', 'LIN'),
#   ('CDNS', 'SNPS'),
#   ('CHTR', 'DDOG'),
#   ('DASH', 'KHC'),
#   ('CDNS', 'MCHP'),
#   ('KHC', 'LIN'),
#   ('CDNS', 'LRCX'),
#   ('LRCX', 'MCHP'),
#   ('ABNB', 'NXPI'),
#   ('FAST', 'NVDA'),
#   ('ABNB', 'BKNG'),
#   ('ABNB', 'ON'),
#   ('ABNB', 'TXN'),
#   ('CDNS', 'CRWD'),
#   ('LULU', 'MCHP'),
#   ('DLTR', 'MCHP'),
#   ('FTNT', 'LIN'),
#   ('FAST', 'TTWO'),
#   ('ABNB', 'MCHP')],
#  '2024-06-04_2024-07-18': [('AMGN', 'EA'),
#   ('GILD', 'HON'),
#   ('CSCO', 'ROP'),
#   ('AZN', 'DLTR'),
#   ('KDP', 'ZS'),
#   ('ABNB', 'AZN'),
#   ('AEP', 'CRWD'),
#   ('FANG', 'WDAY'),
#   ('CCEP', 'DLTR'),
#   ('CMCSA', 'CRWD'),
#   ('ILMN', 'NXPI'),
#   ('AZN', 'MSFT'),
#   ('CSCO', 'DLTR'),
#   ('AMGN', 'DLTR'),
#   ('ADI', 'CRWD'),
#   ('GEHC', 'HON'),
#   ('GOOGL', 'TTD'),
#   ('GOOG', 'TTD'),
#   ('ADSK', 'DLTR'),
#   ('ADP', 'DLTR')],
#  '2024-07-18_2024-08-29': [('AVGO', 'CRWD'),
#   ('CEG', 'CRWD'),
#   ('ANSS', 'CRWD'),
#   ('ADSK', 'CRWD'),
#   ('EA', 'ORLY'),
#   ('COST', 'ISRG'),
#   ('COST', 'CRWD'),
#   ('ARM', 'QCOM'),
#   ('MSFT', 'NXPI'),
#   ('ARM', 'NXPI'),
#   ('CTSH', 'ON'),
#   ('ADI', 'BKNG'),
#   ('ADBE', 'ON'),
#   ('AAPL', 'ON'),
#   ('AAPL', 'ADBE'),
#   ('AAPL', 'CRWD'),
#   ('CCEP', 'CRWD'),
#   ('FTNT', 'IDXX'),
#   ('IDXX', 'ISRG'),
#   ('EXC', 'FANG'),
#   ('ABNB', 'INTC')],
#  '2024-08-29_2024-10-11': [('ARM', 'CTAS'),
#   ('ADSK', 'NFLX'),
#   ('AMZN', 'VRSK'),
#   ('BKNG', 'NFLX'),
#   ('MNST', 'VRSK'),
#   ('INTC', 'LRCX'),
#   ('CSCO', 'NFLX'),
#   ('CSGP', 'MDB'),
#   ('AMAT', 'INTC'),
#   ('TSLA', 'TTWO'),
#   ('INTC', 'KLAC'),
#   ('MSFT', 'VRSK'),
#   ('AVGO', 'NFLX'),
#   ('CDW', 'QCOM'),
#   ('KDP', 'ROP'),
#   ('AMZN', 'ODFL'),
#   ('LIN', 'MCHP'),
#   ('ASML', 'MCHP'),
#   ('ADSK', 'LULU'),
#   ('MDB', 'VRTX')],
#  '2024-10-11_2024-11-22': [('CRWD', 'PDD'),
#   ('CCEP', 'FANG'),
#   ('CSGP', 'FANG'),
#   ('PDD', 'SBUX'),
#   ('MDB', 'PDD'),
#   ('BKR', 'MRVL'),
#   ('ADP', 'TTD'),
#   ('INTC', 'MRVL'),
#   ('AAPL', 'FANG'),
#   ('ADP', 'PCAR'),
#   ('DASH', 'TMUS'),
#   ('CTSH', 'PAYX'),
#   ('ADBE', 'FANG'),
#   ('EA', 'WBD'),
#   ('INTU', 'MELI'),
#   ('PANW', 'PCAR'),
#   ('GEHC', 'SBUX'),
#   ('BKR', 'DASH'),
#   ('BKR', 'WBD'),
#   ('CSCO', 'NVDA')],
#  '2024-11-22_2025-01-08': [('PAYX', 'XEL'),
#   ('AMD', 'CDNS'),
#   ('AMD', 'ANSS'),
#   ('AZN', 'QCOM'),
#   ('MNST', 'PAYX'),
#   ('AXON', 'CDNS'),
#   ('ADP', 'XEL'),
#   ('BKNG', 'CDNS'),
#   ('CSX', 'PAYX'),
#   ('AEP', 'ANSS'),
#   ('CSGP', 'VRSK'),
#   ('AVGO', 'CDNS'),
#   ('ISRG', 'QCOM'),
#   ('ADP', 'CDNS'),
#   ('CCEP', 'CDNS'),
#   ('CSGP', 'MDLZ'),
#   ('AEP', 'PAYX'),
#   ('AEP', 'CDNS'),
#   ('PEP', 'ROP'),
#   ('BIIB', 'CDNS'),
#   ('ADBE', 'AMGN')],
#  '2025-01-08_2025-02-24': [('CRWD', 'CTSH'),
#   ('DASH', 'GEHC'),
#   ('PDD', 'GEHC'),
#   ('ISRG', 'KLAC'),
#   ('AEP', 'INTU'),
#   ('SBUX', 'VRSK'),
#   ('INTU', 'MELI'),
#   ('APP', 'GEHC'),
#   ('SBUX', 'ROP'),
#   ('AZN', 'PDD'),
#   ('AMZN', 'ADSK'),
#   ('ABNB', 'GEHC'),
#   ('ABNB', 'BKNG'),
#   ('EXC', 'INTU'),
#   ('ADBE', 'CTAS'),
#   ('INTU', 'LIN'),
#   ('META', 'ZS'),
#   ('CCEP', 'GEHC'),
#   ('AMGN', 'INTU'),
#   ('AVGO', 'CEG')],
#  '2025-02-24_2025-04-07': [('PAYX', 'VRSK'),
#   ('CPRT', 'KDP'),
#   ('CMCSA', 'ZS'),
#   ('DXCM', 'TEAM'),
#   ('HON', 'INTU'),
#   ('PYPL', 'SNPS'),
#   ('AMD', 'AXON'),
#   ('INTC', 'AXON'),
#   ('PDD', 'AXON'),
#   ('CDNS', 'AXON'),
#   ('AAPL', 'CSCO'),
#   ('BKR', 'INTU'),
#   ('LIN', 'ROP'),
#   ('CHTR', 'INTU'),
#   ('GFS', 'PYPL'),
#   ('FANG', 'AXON'),
#   ('PLTR', 'AXON'),
#   ('CMCSA', 'INTU'),
#   ('DDOG', 'TXN'),
#   ('WDAY', 'CDW')]}

# %%
with open(
        "C:/Users/edmun/Downloads/j.json", "w"
    ) as json_file:
        json.dump(output, json_file, default=str)

# %%
for i in range(10, len(period_ends)):  # range(2, len(period_ends))
    warm_start, train_start, train_end, trade_end = (
        period_ends[i - 10],
        period_ends[i - 2],
        period_ends[i - 1],
        period_ends[i],
    )

    print(warm_start, train_start, train_end, trade_end)
    # next trading day
    last_date = datetime.strptime(train_end, "%Y-%m-%d")
    next_day = (last_date + timedelta(days=1)).strftime("%Y-%m-%d")

    if os.path.isfile((f"{out_path}/result/result_{next_day}_{trade_end}.csv")):
        continue
    # TRAINING PERIOD FINDING OPTIMAL PARAMS #
    data.read(cons=cons_date[train_end], start=train_start, end=train_end)

    train = data.filter(resample_freq="15m", hours=market_hours.MARKET)

    c = Clustering(df=train.select(pl.all().exclude(["date", "time"])))

    # c.run_clustering(method=Clustering_methods.kmeans, min_clusters=2, max_clusters=6)

    c.run_clustering(method=Clustering_methods.agnes, min_clusters=2, max_clusters=5)

    find_pairs = cointegration_pairs(
        df=train.select(pl.all().exclude(["date", "time"])),
        p_val_cutoff=0.005,
        cluster_pairs=c.cluster_pairs,
    )
    find_pairs.identify_pairs()

    potential_pairs = [
        pair[0]
        for sublist in find_pairs.cluster_sorted_pairs.values()
        for pair in sublist
    ]
    data.read(
        cons=set([item for pair in potential_pairs for item in pair]),
        start=warm_start,
        end=train_end,
    )

    opt = optimizer(
        data=data,
        find_pairs=find_pairs,  # list(params.keys()), # pairs_to_trade
        start=pl.lit(train_start).str.strptime(pl.Date, "%Y-%m-%d"),
        end=pl.lit(train_end).str.strptime(pl.Date, "%Y-%m-%d"),
    )

    study = opt.optimize(
        study_name="PAIRS_TRADING",
        output_file_name=f"{out_path}/db/result_{next_day}_{trade_end}.db",
        n_trials=10,
    )
    p = study.best_params

    study.trials_dataframe().to_csv(
        f"{out_path}/trials/trials_{train_start}_{train_end}.csv"
    )

    optimal_params = {}
    for key, value in p.items():
        if key not in ["pairs_to_trade", "buffer_capital"]:
            parts = key.split("_")

            pair = (parts[0], parts[1])
            param_name = "_".join(parts[2:])

            if pair not in optimal_params:
                optimal_params[pair] = {}

            optimal_params[pair][param_name] = value

    # TRADING PERIOD USING PARAMS

    # reading pairs only from next trading day to next q end
    pairs_to_trade = list(optimal_params.keys())
    data.read(
        cons=set([item for pair in pairs_to_trade for item in pair]),
        start=train_start,
        end=trade_end,
    )

    trader = PairsTrader(
        data=data,
        pairs=pairs_to_trade,  # list(params.keys()),  # pairs_to_trade
        params=optimal_params,
        trade_hour=market_hours.MARKET,
    )

    pl_next_day = pl.lit(next_day).str.strptime(pl.Date, "%Y-%m-%d")
    pl_trade_end = pl.lit(trade_end).str.strptime(pl.Date, "%Y-%m-%d")
    returns = trader.backtest(
        start=pl_next_day,
        end=pl_trade_end,
        cost=0.0005,
        stop_loss=None,
        # np.array(
        #     [optimal_params[(p1, p2)][PARAMS.stop_loss] for p1, p2 in pairs_to_trade]
        # ),
    )

    returns.with_columns(
        pl.col("CAPITAL").pct_change().fill_null(0).alias("PORT_RET")
    ).write_csv(f"{out_path}/result/result_{next_day}_{trade_end}.csv")

    convert_json = {f"{p1}_{p2}": params for (p1, p2), params in optimal_params.items()}
    convert_json["pairs_to_trade"] = p["pairs_to_trade"]
    convert_json["buffer_capital"] = p["buffer_capital"]
    with open(
        f"{out_path}/params/optimal_params_{next_day}_{trade_end}.json", "w"
    ) as json_file:
        json.dump(convert_json, json_file, default=str)

    del c, opt, find_pairs, trader  # free ram
# Out:
# 2020-06-30 2020-07-23 2020-07-27 2020-07-29
# 2020-07-02 2020-07-27 2020-07-29 2020-07-31
# [I 2025-06-14 18:33:05,345] A new study created in RDB with name: PAIRS_TRADING
#   0%|          | 0/10 [00:00<?, ?it/s]
# [I 2025-06-14 18:33:09,671] Trial 0 finished with value: -5.684916362775381 and parameters: {'pairs_to_trade': 3, 'AMGN_COST_beta_win': 336, 'AMGN_COST_z_win': 498, 'AMGN_COST_z_entry': 3.5, 'AMGN_COST_z_exit': 2.0, 'AMGN_COST_trade_freq': '3m', 'AMGN_COST_stop_loss': 0.02, 'PCAR_VRSN_beta_win': 874, 'PCAR_VRSN_z_win': 390, 'PCAR_VRSN_z_entry': 1.0, 'PCAR_VRSN_z_exit': 3.0, 'PCAR_VRSN_trade_freq': '3m', 'PCAR_VRSN_stop_loss': 0.005, 'FOXA_VRSN_beta_win': 1000, 'FOXA_VRSN_z_win': 464, 'FOXA_VRSN_z_entry': 2.5, 'FOXA_VRSN_z_exit': 2.0, 'FOXA_VRSN_trade_freq': '1m', 'FOXA_VRSN_stop_loss': 0.005, 'AMGN_COST_z_stop_scaler': 1.3, 'PCAR_VRSN_z_stop_scaler': 1.3, 'FOXA_VRSN_z_stop_scaler': 0.6, 'buffer_capital': 0.5}. Best is trial 0 with value: -5.684916362775381.
# [I 2025-06-14 18:33:09,924] Trial 1 finished with value: -7.068437654392485 and parameters: {'pairs_to_trade': 3, 'AMGN_COST_beta_win': 320, 'AMGN_COST_z_win': 314, 'AMGN_COST_z_entry': 4.0, 'AMGN_COST_z_exit': 1.5, 'AMGN_COST_trade_freq': '2m', 'AMGN_COST_stop_loss': 0.02, 'PCAR_VRSN_beta_win': 202, 'PCAR_VRSN_z_win': 948, 'PCAR_VRSN_z_entry': 3.0, 'PCAR_VRSN_z_exit': 3.0, 'PCAR_VRSN_trade_freq': '1m', 'PCAR_VRSN_stop_loss': 0.02, 'FOXA_VRSN_beta_win': 984, 'FOXA_VRSN_z_win': 588, 'FOXA_VRSN_z_entry': 2.5, 'FOXA_VRSN_z_exit': 3.0, 'FOXA_VRSN_trade_freq': '3m', 'FOXA_VRSN_stop_loss': 0.015, 'AMGN_COST_z_stop_scaler': 1.9000000000000001, 'PCAR_VRSN_z_stop_scaler': 1.9000000000000001, 'FOXA_VRSN_z_stop_scaler': 1.0, 'buffer_capital': 0.3}. Best is trial 0 with value: -5.684916362775381.
# [I 2025-06-14 18:33:10,552] Trial 2 finished with value: 1.3680702872290953 and parameters: {'pairs_to_trade': 9, 'AMGN_COST_beta_win': 264, 'AMGN_COST_z_win': 44, 'AMGN_COST_z_entry': 1.0, 'AMGN_COST_z_exit': 1.5, 'AMGN_COST_trade_freq': '4m', 'AMGN_COST_stop_loss': 0.02, 'PCAR_VRSN_beta_win': 978, 'PCAR_VRSN_z_win': 696, 'PCAR_VRSN_z_entry': 1.5, 'PCAR_VRSN_z_exit': 4.0, 'PCAR_VRSN_trade_freq': '3m', 'PCAR_VRSN_stop_loss': 0.015, 'FOXA_VRSN_beta_win': 568, 'FOXA_VRSN_z_win': 382, 'FOXA_VRSN_z_entry': 1.5, 'FOXA_VRSN_z_exit': 3.5, 'FOXA_VRSN_trade_freq': '4m', 'FOXA_VRSN_stop_loss': 0.02, 'KHC_VRSN_beta_win': 26, 'KHC_VRSN_z_win': 224, 'KHC_VRSN_z_entry': 3.0, 'KHC_VRSN_z_exit': 3.5, 'KHC_VRSN_trade_freq': '2m', 'KHC_VRSN_stop_loss': 0.01, 'FOX_VRSN_beta_win': 102, 'FOX_VRSN_z_win': 140, 'FOX_VRSN_z_entry': 1.0, 'FOX_VRSN_z_exit': 4.0, 'FOX_VRSN_trade_freq': '4m', 'FOX_VRSN_stop_loss': 0.005, 'EBAY_VRSN_beta_win': 918, 'EBAY_VRSN_z_win': 354, 'EBAY_VRSN_z_entry': 2.5, 'EBAY_VRSN_z_exit': 1.0, 'EBAY_VRSN_trade_freq': '3m', 'EBAY_VRSN_stop_loss': 0.01, 'MDLZ_VRSN_beta_win': 668, 'MDLZ_VRSN_z_win': 544, 'MDLZ_VRSN_z_entry': 2.0, 'MDLZ_VRSN_z_exit': 2.5, 'MDLZ_VRSN_trade_freq': '4m', 'MDLZ_VRSN_stop_loss': 0.015, 'INTC_VRSN_beta_win': 650, 'INTC_VRSN_z_win': 826, 'INTC_VRSN_z_entry': 3.0, 'INTC_VRSN_z_exit': 1.5, 'INTC_VRSN_trade_freq': '4m', 'INTC_VRSN_stop_loss': 0.005, 'PAYX_VRSN_beta_win': 68, 'PAYX_VRSN_z_win': 384, 'PAYX_VRSN_z_entry': 2.5, 'PAYX_VRSN_z_exit': 2.5, 'PAYX_VRSN_trade_freq': '3m', 'PAYX_VRSN_stop_loss': 0.005, 'AMGN_COST_z_stop_scaler': 0.5, 'PCAR_VRSN_z_stop_scaler': 0.7, 'FOXA_VRSN_z_stop_scaler': 2.0, 'KHC_VRSN_z_stop_scaler': 0.8, 'FOX_VRSN_z_stop_scaler': 1.6, 'EBAY_VRSN_z_stop_scaler': 1.3, 'MDLZ_VRSN_z_stop_scaler': 0.8, 'INTC_VRSN_z_stop_scaler': 0.5, 'PAYX_VRSN_z_stop_scaler': 0.6, 'buffer_capital': 0.2}. Best is trial 2 with value: 1.3680702872290953.
# [I 2025-06-14 18:33:10,916] Trial 3 finished with value: -3.0836029281739235 and parameters: {'pairs_to_trade': 5, 'AMGN_COST_beta_win': 540, 'AMGN_COST_z_win': 320, 'AMGN_COST_z_entry': 1.5, 'AMGN_COST_z_exit': 3.5, 'AMGN_COST_trade_freq': '1m', 'AMGN_COST_stop_loss': 0.02, 'PCAR_VRSN_beta_win': 842, 'PCAR_VRSN_z_win': 578, 'PCAR_VRSN_z_entry': 3.5, 'PCAR_VRSN_z_exit': 4.0, 'PCAR_VRSN_trade_freq': '4m', 'PCAR_VRSN_stop_loss': 0.02, 'FOXA_VRSN_beta_win': 346, 'FOXA_VRSN_z_win': 854, 'FOXA_VRSN_z_entry': 1.0, 'FOXA_VRSN_z_exit': 3.5, 'FOXA_VRSN_trade_freq': '2m', 'FOXA_VRSN_stop_loss': 0.015, 'KHC_VRSN_beta_win': 958, 'KHC_VRSN_z_win': 254, 'KHC_VRSN_z_entry': 2.5, 'KHC_VRSN_z_exit': 1.5, 'KHC_VRSN_trade_freq': '4m', 'KHC_VRSN_stop_loss': 0.02, 'FOX_VRSN_beta_win': 430, 'FOX_VRSN_z_win': 974, 'FOX_VRSN_z_entry': 2.5, 'FOX_VRSN_z_exit': 3.5, 'FOX_VRSN_trade_freq': '3m', 'FOX_VRSN_stop_loss': 0.015, 'AMGN_COST_z_stop_scaler': 1.3, 'PCAR_VRSN_z_stop_scaler': 1.9000000000000001, 'FOXA_VRSN_z_stop_scaler': 1.3, 'KHC_VRSN_z_stop_scaler': 1.3, 'FOX_VRSN_z_stop_scaler': 0.7, 'buffer_capital': 0.05}. Best is trial 2 with value: 1.3680702872290953.
# [I 2025-06-14 18:33:11,258] Trial 4 finished with value: -2.5555938050389955 and parameters: {'pairs_to_trade': 5, 'AMGN_COST_beta_win': 972, 'AMGN_COST_z_win': 700, 'AMGN_COST_z_entry': 1.5, 'AMGN_COST_z_exit': 2.0, 'AMGN_COST_trade_freq': '4m', 'AMGN_COST_stop_loss': 0.02, 'PCAR_VRSN_beta_win': 50, 'PCAR_VRSN_z_win': 220, 'PCAR_VRSN_z_entry': 3.5, 'PCAR_VRSN_z_exit': 3.0, 'PCAR_VRSN_trade_freq': '4m', 'PCAR_VRSN_stop_loss': 0.015, 'FOXA_VRSN_beta_win': 750, 'FOXA_VRSN_z_win': 992, 'FOXA_VRSN_z_entry': 2.5, 'FOXA_VRSN_z_exit': 3.0, 'FOXA_VRSN_trade_freq': '1m', 'FOXA_VRSN_stop_loss': 0.02, 'KHC_VRSN_beta_win': 956, 'KHC_VRSN_z_win': 590, 'KHC_VRSN_z_entry': 1.5, 'KHC_VRSN_z_exit': 1.5, 'KHC_VRSN_trade_freq': '1m', 'KHC_VRSN_stop_loss': 0.02, 'FOX_VRSN_beta_win': 884, 'FOX_VRSN_z_win': 448, 'FOX_VRSN_z_entry': 3.5, 'FOX_VRSN_z_exit': 2.5, 'FOX_VRSN_trade_freq': '3m', 'FOX_VRSN_stop_loss': 0.01, 'AMGN_COST_z_stop_scaler': 1.9000000000000001, 'PCAR_VRSN_z_stop_scaler': 1.7000000000000002, 'FOXA_VRSN_z_stop_scaler': 1.1, 'KHC_VRSN_z_stop_scaler': 1.9000000000000001, 'FOX_VRSN_z_stop_scaler': 1.1, 'buffer_capital': 0.2}. Best is trial 2 with value: 1.3680702872290953.
# [I 2025-06-14 18:33:11,838] Trial 5 finished with value: -2.7022538641555585 and parameters: {'pairs_to_trade': 8, 'AMGN_COST_beta_win': 426, 'AMGN_COST_z_win': 272, 'AMGN_COST_z_entry': 2.5, 'AMGN_COST_z_exit': 4.0, 'AMGN_COST_trade_freq': '4m', 'AMGN_COST_stop_loss': 0.005, 'PCAR_VRSN_beta_win': 212, 'PCAR_VRSN_z_win': 64, 'PCAR_VRSN_z_entry': 1.5, 'PCAR_VRSN_z_exit': 3.0, 'PCAR_VRSN_trade_freq': '2m', 'PCAR_VRSN_stop_loss': 0.01, 'FOXA_VRSN_beta_win': 802, 'FOXA_VRSN_z_win': 546, 'FOXA_VRSN_z_entry': 2.5, 'FOXA_VRSN_z_exit': 3.5, 'FOXA_VRSN_trade_freq': '1m', 'FOXA_VRSN_stop_loss': 0.015, 'KHC_VRSN_beta_win': 600, 'KHC_VRSN_z_win': 98, 'KHC_VRSN_z_entry': 4.0, 'KHC_VRSN_z_exit': 2.0, 'KHC_VRSN_trade_freq': '1m', 'KHC_VRSN_stop_loss': 0.015, 'FOX_VRSN_beta_win': 24, 'FOX_VRSN_z_win': 214, 'FOX_VRSN_z_entry': 3.0, 'FOX_VRSN_z_exit': 3.5, 'FOX_VRSN_trade_freq': '1m', 'FOX_VRSN_stop_loss': 0.015, 'EBAY_VRSN_beta_win': 972, 'EBAY_VRSN_z_win': 920, 'EBAY_VRSN_z_entry': 3.0, 'EBAY_VRSN_z_exit': 4.0, 'EBAY_VRSN_trade_freq': '4m', 'EBAY_VRSN_stop_loss': 0.015, 'MDLZ_VRSN_beta_win': 298, 'MDLZ_VRSN_z_win': 646, 'MDLZ_VRSN_z_entry': 1.5, 'MDLZ_VRSN_z_exit': 1.0, 'MDLZ_VRSN_trade_freq': '4m', 'MDLZ_VRSN_stop_loss': 0.015, 'INTC_VRSN_beta_win': 366, 'INTC_VRSN_z_win': 486, 'INTC_VRSN_z_entry': 2.0, 'INTC_VRSN_z_exit': 1.0, 'INTC_VRSN_trade_freq': '1m', 'INTC_VRSN_stop_loss': 0.015, 'AMGN_COST_z_stop_scaler': 0.8, 'PCAR_VRSN_z_stop_scaler': 1.6, 'FOXA_VRSN_z_stop_scaler': 0.6, 'KHC_VRSN_z_stop_scaler': 1.9000000000000001, 'FOX_VRSN_z_stop_scaler': 1.5, 'EBAY_VRSN_z_stop_scaler': 1.8, 'MDLZ_VRSN_z_stop_scaler': 1.8, 'INTC_VRSN_z_stop_scaler': 1.4, 'buffer_capital': 0.15000000000000002}. Best is trial 2 with value: 1.3680702872290953.
# [I 2025-06-14 18:33:12,141] Trial 6 finished with value: 0.2057580881872702 and parameters: {'pairs_to_trade': 4, 'AMGN_COST_beta_win': 256, 'AMGN_COST_z_win': 716, 'AMGN_COST_z_entry': 4.0, 'AMGN_COST_z_exit': 1.0, 'AMGN_COST_trade_freq': '1m', 'AMGN_COST_stop_loss': 0.02, 'PCAR_VRSN_beta_win': 584, 'PCAR_VRSN_z_win': 596, 'PCAR_VRSN_z_entry': 2.5, 'PCAR_VRSN_z_exit': 2.5, 'PCAR_VRSN_trade_freq': '2m', 'PCAR_VRSN_stop_loss': 0.015, 'FOXA_VRSN_beta_win': 50, 'FOXA_VRSN_z_win': 272, 'FOXA_VRSN_z_entry': 2.5, 'FOXA_VRSN_z_exit': 1.5, 'FOXA_VRSN_trade_freq': '3m', 'FOXA_VRSN_stop_loss': 0.02, 'KHC_VRSN_beta_win': 248, 'KHC_VRSN_z_win': 888, 'KHC_VRSN_z_entry': 2.0, 'KHC_VRSN_z_exit': 3.5, 'KHC_VRSN_trade_freq': '2m', 'KHC_VRSN_stop_loss': 0.02, 'AMGN_COST_z_stop_scaler': 0.6, 'PCAR_VRSN_z_stop_scaler': 0.8, 'FOXA_VRSN_z_stop_scaler': 1.1, 'KHC_VRSN_z_stop_scaler': 1.6, 'buffer_capital': 0.45}. Best is trial 2 with value: 1.3680702872290953.
# [I 2025-06-14 18:33:12,387] Trial 7 finished with value: -10.529533385907468 and parameters: {'pairs_to_trade': 3, 'AMGN_COST_beta_win': 952, 'AMGN_COST_z_win': 650, 'AMGN_COST_z_entry': 2.0, 'AMGN_COST_z_exit': 2.5, 'AMGN_COST_trade_freq': '3m', 'AMGN_COST_stop_loss': 0.01, 'PCAR_VRSN_beta_win': 830, 'PCAR_VRSN_z_win': 510, 'PCAR_VRSN_z_entry': 3.5, 'PCAR_VRSN_z_exit': 2.5, 'PCAR_VRSN_trade_freq': '3m', 'PCAR_VRSN_stop_loss': 0.02, 'FOXA_VRSN_beta_win': 948, 'FOXA_VRSN_z_win': 758, 'FOXA_VRSN_z_entry': 4.0, 'FOXA_VRSN_z_exit': 3.0, 'FOXA_VRSN_trade_freq': '2m', 'FOXA_VRSN_stop_loss': 0.015, 'AMGN_COST_z_stop_scaler': 0.8, 'PCAR_VRSN_z_stop_scaler': 1.5, 'FOXA_VRSN_z_stop_scaler': 1.6, 'buffer_capital': 0.1}. Best is trial 2 with value: 1.3680702872290953.
# [I 2025-06-14 18:33:12,879] Trial 8 finished with value: -2.684630461091376 and parameters: {'pairs_to_trade': 7, 'AMGN_COST_beta_win': 180, 'AMGN_COST_z_win': 60, 'AMGN_COST_z_entry': 3.0, 'AMGN_COST_z_exit': 3.0, 'AMGN_COST_trade_freq': '3m', 'AMGN_COST_stop_loss': 0.02, 'PCAR_VRSN_beta_win': 164, 'PCAR_VRSN_z_win': 890, 'PCAR_VRSN_z_entry': 2.5, 'PCAR_VRSN_z_exit': 4.0, 'PCAR_VRSN_trade_freq': '2m', 'PCAR_VRSN_stop_loss': 0.005, 'FOXA_VRSN_beta_win': 144, 'FOXA_VRSN_z_win': 440, 'FOXA_VRSN_z_entry': 4.0, 'FOXA_VRSN_z_exit': 3.0, 'FOXA_VRSN_trade_freq': '2m', 'FOXA_VRSN_stop_loss': 0.005, 'KHC_VRSN_beta_win': 134, 'KHC_VRSN_z_win': 860, 'KHC_VRSN_z_entry': 3.0, 'KHC_VRSN_z_exit': 3.0, 'KHC_VRSN_trade_freq': '1m', 'KHC_VRSN_stop_loss': 0.015, 'FOX_VRSN_beta_win': 570, 'FOX_VRSN_z_win': 288, 'FOX_VRSN_z_entry': 2.0, 'FOX_VRSN_z_exit': 1.5, 'FOX_VRSN_trade_freq': '4m', 'FOX_VRSN_stop_loss': 0.02, 'EBAY_VRSN_beta_win': 332, 'EBAY_VRSN_z_win': 488, 'EBAY_VRSN_z_entry': 1.5, 'EBAY_VRSN_z_exit': 3.0, 'EBAY_VRSN_trade_freq': '2m', 'EBAY_VRSN_stop_loss': 0.01, 'MDLZ_VRSN_beta_win': 364, 'MDLZ_VRSN_z_win': 672, 'MDLZ_VRSN_z_entry': 2.0, 'MDLZ_VRSN_z_exit': 3.0, 'MDLZ_VRSN_trade_freq': '3m', 'MDLZ_VRSN_stop_loss': 0.015, 'AMGN_COST_z_stop_scaler': 1.2000000000000002, 'PCAR_VRSN_z_stop_scaler': 1.8, 'FOXA_VRSN_z_stop_scaler': 1.4, 'KHC_VRSN_z_stop_scaler': 1.7000000000000002, 'FOX_VRSN_z_stop_scaler': 1.2000000000000002, 'EBAY_VRSN_z_stop_scaler': 1.4, 'MDLZ_VRSN_z_stop_scaler': 1.2000000000000002, 'buffer_capital': 0.05}. Best is trial 2 with value: 1.3680702872290953.
# [I 2025-06-14 18:33:13,576] Trial 9 finished with value: -16.037212485282744 and parameters: {'pairs_to_trade': 10, 'AMGN_COST_beta_win': 82, 'AMGN_COST_z_win': 842, 'AMGN_COST_z_entry': 4.0, 'AMGN_COST_z_exit': 1.5, 'AMGN_COST_trade_freq': '2m', 'AMGN_COST_stop_loss': 0.01, 'PCAR_VRSN_beta_win': 696, 'PCAR_VRSN_z_win': 764, 'PCAR_VRSN_z_entry': 2.5, 'PCAR_VRSN_z_exit': 3.5, 'PCAR_VRSN_trade_freq': '4m', 'PCAR_VRSN_stop_loss': 0.02, 'FOXA_VRSN_beta_win': 1010, 'FOXA_VRSN_z_win': 764, 'FOXA_VRSN_z_entry': 4.0, 'FOXA_VRSN_z_exit': 1.5, 'FOXA_VRSN_trade_freq': '3m', 'FOXA_VRSN_stop_loss': 0.015, 'KHC_VRSN_beta_win': 1012, 'KHC_VRSN_z_win': 242, 'KHC_VRSN_z_entry': 4.0, 'KHC_VRSN_z_exit': 1.5, 'KHC_VRSN_trade_freq': '4m', 'KHC_VRSN_stop_loss': 0.01, 'FOX_VRSN_beta_win': 56, 'FOX_VRSN_z_win': 312, 'FOX_VRSN_z_entry': 3.0, 'FOX_VRSN_z_exit': 1.0, 'FOX_VRSN_trade_freq': '2m', 'FOX_VRSN_stop_loss': 0.015, 'EBAY_VRSN_beta_win': 406, 'EBAY_VRSN_z_win': 746, 'EBAY_VRSN_z_entry': 1.0, 'EBAY_VRSN_z_exit': 3.5, 'EBAY_VRSN_trade_freq': '4m', 'EBAY_VRSN_stop_loss': 0.015, 'MDLZ_VRSN_beta_win': 610, 'MDLZ_VRSN_z_win': 74, 'MDLZ_VRSN_z_entry': 1.0, 'MDLZ_VRSN_z_exit': 1.5, 'MDLZ_VRSN_trade_freq': '2m', 'MDLZ_VRSN_stop_loss': 0.01, 'INTC_VRSN_beta_win': 548, 'INTC_VRSN_z_win': 378, 'INTC_VRSN_z_entry': 2.0, 'INTC_VRSN_z_exit': 3.5, 'INTC_VRSN_trade_freq': '1m', 'INTC_VRSN_stop_loss': 0.005, 'PAYX_VRSN_beta_win': 674, 'PAYX_VRSN_z_win': 414, 'PAYX_VRSN_z_entry': 4.0, 'PAYX_VRSN_z_exit': 4.0, 'PAYX_VRSN_trade_freq': '4m', 'PAYX_VRSN_stop_loss': 0.02, 'EXC_VRSN_beta_win': 428, 'EXC_VRSN_z_win': 218, 'EXC_VRSN_z_entry': 4.0, 'EXC_VRSN_z_exit': 1.5, 'EXC_VRSN_trade_freq': '4m', 'EXC_VRSN_stop_loss': 0.015, 'AMGN_COST_z_stop_scaler': 0.9, 'PCAR_VRSN_z_stop_scaler': 0.8, 'FOXA_VRSN_z_stop_scaler': 0.8, 'KHC_VRSN_z_stop_scaler': 0.5, 'FOX_VRSN_z_stop_scaler': 1.9000000000000001, 'EBAY_VRSN_z_stop_scaler': 1.7000000000000002, 'MDLZ_VRSN_z_stop_scaler': 1.6, 'INTC_VRSN_z_stop_scaler': 0.7, 'PAYX_VRSN_z_stop_scaler': 2.0, 'EXC_VRSN_z_stop_scaler': 0.9, 'buffer_capital': 0.45}. Best is trial 2 with value: 1.3680702872290953.
# 2020-07-07 2020-07-29 2020-07-31 2020-08-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 17
#      15     continue
#      16 # TRAINING PERIOD FINDING OPTIMAL PARAMS #
# ---> 17 data.read(cons=cons_date[train_end], start=train_start, end=train_end)
#      19 train = data.filter(resample_freq="15m", hours=market_hours.MARKET)
#      21 c = Clustering(df=train.select(pl.all().exclude(["date", "time"])))
#
# File c:\Users\edmun\OneDrive\Desktop\Quantitative Trading Strategies\Project\qts\data\market_data.py:148, in market_data.read(self, cons, start, end)
#     125 pl_end = pl.lit(end).str.strptime(pl.Date, "%Y-%m-%d")
#     127 self.df = self.pq_scanner.select(
#     128     [
#     129         "t",
#    (...)
#     132     ]
#     133 ).with_columns(date=pl.col("t").dt.date(), time=pl.col("t").dt.time())
#     135 self.df = (
#     136     self.df.filter(
#     137         (
#     138             pl.col("date").is_between(
#     139                 lower_bound=pl_start
#     140                 - pl.duration(
#     141                     days=5
#     142                 ),  # filter few days behind to get the ffill price
#     143                 upper_bound=pl_end,
#     144             )
#     145             & (pl.col("symbol").is_in(cons))
#     146         )
#     147     )
# --> 148     .collect(streaming=True)
#     149     .pivot(on="symbol", index=["date", "time"], values="close")
#     150     .sort(by=["date", "time"])
#     151     .with_columns(
#     152         year=pl.col("date").dt.year(),
#     153         is_dst=pl.lit(0).cast(pl.Int16),
#     154     )
#     155     .lazy()
#     156 )
#     158 for year, dates in self.dst_dates.items():
#     159     self.df = self.df.with_columns(
#     160         pl.when(
#     161             (pl.col("year") == year)
#    (...)
#     171         .alias("is_dst")
#     172     )
#
# File c:\Users\edmun\anaconda3\Lib\site-packages\polars\lazyframe\frame.py:2031, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2029 # Only for testing purposes
#    2030 callback = _kwargs.get("post_opt_callback", callback)
# -> 2031 return wrap_df(ldf.collect(callback))
#
# KeyboardInterrupt:

# %%
with open(
    "C:/Users/edmun/OneDrive/Desktop/Quantitative Trading Strategies/Project/qts/output/polygon/params/optimal_params_2020-07-30_2020-07-31.json"
) as r:
    p = json.load(r)
p
# Out:
# {'AMGN_COST': {'beta_win': 264,
#   'z_win': 44,
#   'z_entry': 1.0,
#   'z_exit': 1.5,
#   'trade_freq': '4m',
#   'stop_loss': 0.02,
#   'z_stop_scaler': 0.5},
#  'PCAR_VRSN': {'beta_win': 978,
#   'z_win': 696,
#   'z_entry': 1.5,
#   'z_exit': 4.0,
#   'trade_freq': '3m',
#   'stop_loss': 0.015,
#   'z_stop_scaler': 0.7},
#  'FOXA_VRSN': {'beta_win': 568,
#   'z_win': 382,
#   'z_entry': 1.5,
#   'z_exit': 3.5,
#   'trade_freq': '4m',
#   'stop_loss': 0.02,
#   'z_stop_scaler': 2.0},
#  'KHC_VRSN': {'beta_win': 26,
#   'z_win': 224,
#   'z_entry': 3.0,
#   'z_exit': 3.5,
#   'trade_freq': '2m',
#   'stop_loss': 0.01,
#   'z_stop_scaler': 0.8},
#  'FOX_VRSN': {'beta_win': 102,
#   'z_win': 140,
#   'z_entry': 1.0,
#   'z_exit': 4.0,
#   'trade_freq': '4m',
#   'stop_loss': 0.005,
#   'z_stop_scaler': 1.6},
#  'EBAY_VRSN': {'beta_win': 918,
#   'z_win': 354,
#   'z_entry': 2.5,
#   'z_exit': 1.0,
#   'trade_freq': '3m',
#   'stop_loss': 0.01,
#   'z_stop_scaler': 1.3},
#  'MDLZ_VRSN': {'beta_win': 668,
#   'z_win': 544,
#   'z_entry': 2.0,
#   'z_exit': 2.5,
#   'trade_freq': '4m',
#   'stop_loss': 0.015,
#   'z_stop_scaler': 0.8},
#  'INTC_VRSN': {'beta_win': 650,
#   'z_win': 826,
#   'z_entry': 3.0,
#   'z_exit': 1.5,
#   'trade_freq': '4m',
#   'stop_loss': 0.005,
#   'z_stop_scaler': 0.5},
#  'PAYX_VRSN': {'beta_win': 68,
#   'z_win': 384,
#   'z_entry': 2.5,
#   'z_exit': 2.5,
#   'trade_freq': '3m',
#   'stop_loss': 0.005,
#   'z_stop_scaler': 0.6},
#  'pairs_to_trade': 9,
#  'buffer_capital': 0.2}

# %%
pairs_to_trade = list([pair for pair in optimal_params.keys() if len(pair) == 2])

trader = PairsTrader(
    data=data,
    pairs=pairs_to_trade,  # list(params.keys()),  # pairs_to_trade
    params=optimal_params,
    trade_hour=market_hours.MARKET,
)

pl_next_day = pl.lit(next_day).str.strptime(pl.Date, "%Y-%m-%d")
pl_trade_end = pl.lit(trade_end).str.strptime(pl.Date, "%Y-%m-%d")
returns = trader.backtest(
    start=pl_next_day,
    end=pl_trade_end,
    cost=0.000,
    stop_loss=np.array(
        [optimal_params[(p1, p2)][PARAMS.stop_loss] for p1, p2 in pairs_to_trade]
    ),
)
returns
# Out:
# shape: (782, 61)
# ┌────────────┬──────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ date       ┆ time     ┆ PRICE_INC ┆ PRICE_VRT ┆ … ┆ CAPITAL_S ┆ CAPITAL_I ┆ REMAINING ┆ CAPITAL  │
# │ ---        ┆ ---      ┆ Y_INCY_ON ┆ X_INCY_ON ┆   ┆ NPS_ON_VR ┆ NCY_ON_VR ┆ _CAPITAL  ┆ ---      │
# │ date       ┆ time     ┆ _VRTX     ┆ _VRTX     ┆   ┆ TX        ┆ TX        ┆ ---       ┆ f64      │
# │            ┆          ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ f64       ┆          │
# │            ┆          ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆           ┆          │
# ╞════════════╪══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2020-07-28 ┆ 13:29:00 ┆ 101.61    ┆ 283.58    ┆ … ┆ 0.0       ┆ 0.0       ┆ 1.0       ┆ 1.0      │
# │ 2020-07-28 ┆ 13:30:00 ┆ 102.3185  ┆ 283.29    ┆ … ┆ 0.0       ┆ 0.0       ┆ 1.0       ┆ 1.0      │
# │ 2020-07-28 ┆ 13:31:00 ┆ 102.28    ┆ 283.29    ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.1       ┆ 1.0      │
# │ 2020-07-28 ┆ 13:32:00 ┆ 101.88    ┆ 282.67    ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.1       ┆ 0.99967  │
# │ 2020-07-28 ┆ 13:33:00 ┆ 101.87    ┆ 282.27    ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.996344  ┆ 0.996344 │
# │ …          ┆ …        ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2020-07-29 ┆ 19:55:00 ┆ 97.92     ┆ 278.63    ┆ … ┆ 0.892232  ┆ 0.0       ┆ 0.099244  ┆ 0.991476 │
# │ 2020-07-29 ┆ 19:56:00 ┆ 98.04     ┆ 278.63    ┆ … ┆ 0.892116  ┆ 0.0       ┆ 0.099244  ┆ 0.991361 │
# │ 2020-07-29 ┆ 19:57:00 ┆ 98.08     ┆ 278.3901  ┆ … ┆ 0.892157  ┆ 0.0       ┆ 0.099244  ┆ 0.991402 │
# │ 2020-07-29 ┆ 19:58:00 ┆ 98.07     ┆ 278.6     ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.991401  ┆ 0.991401 │
# │ 2020-07-29 ┆ 19:59:00 ┆ 98.05     ┆ 278.72    ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.991401  ┆ 0.991401 │
# └────────────┴──────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
p = {
    "pairs_to_trade": 1,
    "CPRT_SBUX_beta_win": 30,
    "CPRT_SBUX_hurst_win": 50,
    "CPRT_SBUX_z_win": 45,
    # "CPRT_SBUX_z_win": 50,
    "CPRT_SBUX_z_entry": 3.0,
    "CPRT_SBUX_z_exit": -1.7,
    "CPRT_SBUX_trade_freq": "7m",
    "CPRT_SBUX_stop_loss": 0.01,
    "MRNA_TSLA_beta_win": 40,
    "MRNA_TSLA_hurst_win": 10,
    "MRNA_TSLA_z_win": 5,
    # "MRNA_TSLA_z_win": 5,
    "MRNA_TSLA_z_entry": 2.8,
    "MRNA_TSLA_z_exit": -2.5,
    "MRNA_TSLA_trade_freq": "1m",
    "MRNA_TSLA_stop_loss": 0.004,
}

train_start, train_end, trade_end = "2020-06-30", "2020-07-31", "2020-08-31"

# %%
optimal_params = {}
for key, value in p.items():
    if key != "pairs_to_trade":
        parts = key.split("_")

        pair = (parts[0], parts[1])
        param_name = "_".join(parts[2:])

        if pair not in optimal_params:
            optimal_params[pair] = {}

        optimal_params[pair][param_name] = value

# TRADING PERIOD USING PARAMS
# next trading day
last_date = datetime.strptime(train_end, "%Y-%m-%d")
next_day = (last_date + timedelta(days=1)).strftime("%Y-%m-%d")

# reading pairs only from next trading day to next q end
pairs_to_trade = list(optimal_params.keys())

data.read(
    cons=set([item for pair in pairs_to_trade for item in pair]),
    start=train_start,
    end=train_end,
)

trader = PairsTrader(
    data=data,
    pairs=pairs_to_trade,  # list(params.keys()),  # pairs_to_trade
    params=optimal_params,
    trade_hour=market_hours.MARKET,
)

pl_next_day = pl.lit(train_start).str.strptime(pl.Date, "%Y-%m-%d")
pl_trade_end = pl.lit(train_end).str.strptime(pl.Date, "%Y-%m-%d")
returns = trader.backtest(
    start=pl_next_day,
    end=pl_trade_end,
    cost=0.0005,
    stop_loss=np.array(
        [optimal_params[(p1, p2)][PARAMS.stop_loss] for p1, p2 in pairs_to_trade]
    ),
)

# %%
trader.generate_backtest_df()

# %%
trader = PairsTrader(
    data=data,
    pairs=pairs_to_trade,  # list(params.keys()),  # pairs_to_trade
    params=optimal_params,
    trade_hour=market_hours.MARKET,
)

pl_next_day = pl.lit(train_start).str.strptime(pl.Date, "%Y-%m-%d")
pl_trade_end = pl.lit(train_end).str.strptime(pl.Date, "%Y-%m-%d")
returns = trader.backtest(
    start=pl_next_day,
    end=pl_trade_end,
    cost=0.0005,
    stop_loss=np.array(
        [optimal_params[(p1, p2)][PARAMS.stop_loss] for p1, p2 in pairs_to_trade]
    ),
)

# %%
returns.write_csv("check.csv")

# %%
df = trader.generate_backtest_df()

# %%
df

# %%
Z_arr = df.select(
    # select reorders the columns
    [f"Z_MRNA_ON_TSLA", "Z_CPRT_ON_SBUX"]
).to_numpy()  # shape: n rows, n pairs

beta_arr = df.select(
    # select reorders the columns
    [f"BETA_MRNA_ON_TSLA", "Z_CPRT_ON_SBUX"]
).to_numpy()  # shape: n rows, n pairs

# hurst_arr = df.select(
#     # select reorders the columns
#     [f"HURST_MRNA_ON_TSLA" for p1, p2 in self.pairs]
# ).to_numpy()  # shape: n rows, n pairs

# market_close_flag = df.select("market_close").to_numpy().flatten()

z_entry_arr = np.array([1, 1])
z_exit_arr = np.array([0.6, 2])

signal_arr, pos_arr, pos_beta_arr = trader.compute_pos(
    Z_arr=Z_arr,
    beta_arr=beta_arr,
    # hurst_arr=hurst_arr,
    n_pairs=2,
    z_entry_arr=z_entry_arr,
    z_exit_arr=z_exit_arr,
    market_close_flag=np.zeros(len(df)),
)

# %%
pos_arr

# %%
pl.DataFrame(pos_arr).write_csv("hmm.csv")

# %%
mask = np.isnan(pos_arr)
idx = np.where(~mask, np.arange(mask.shape[1]), 0)
np.maximum.accumulate(idx, axis=1, out=idx)
pos_arr[mask] = pos_arr[np.nonzero(mask)[0], idx[mask]]
pl.DataFrame(pos_arr).write_csv("wfill.csv")

# %%
pl.DataFrame(pos_arr).to_pandas().plot()

# %%
pl.DataFrame(pos_beta_arr)

# %%
mask = np.isnan(pos_arr)
idx = np.where(~mask, np.arange(mask.shape[1]), 0)
np.maximum.accumulate(idx, axis=1, out=idx)
pos_arr[mask] = pos_arr[np.nonzero(mask)[0], idx[mask]]
pos_arr[np.isnan(pos_arr)] = 0

pos_arr
